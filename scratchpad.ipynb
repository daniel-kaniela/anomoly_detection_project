# %% [markdown]
# ### Questions for Board Meeting
# ### MVP
# - 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?
# - 2. Which lessons are least accessed?
# - 3. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?
# - 4. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
# - 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?

# %% [markdown]
# ### Follow through
#
# - 1. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
# - 2. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns
import env
import os

from env import host, user, password

# DBSCAN import
from sklearn.cluster import DBSCAN

# Scaler import
from sklearn.preprocessing import MinMaxScaler

import acquire

# %%
#acquire function built
df = acquire.acquire()

# %%
df
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 847325  2021-04-21  16:41:51
# 847326  2021-04-21  16:42:02
# 847327  2021-04-21  16:42:09
# 847328  2021-04-21  16:44:37
# 847329  2021-04-21  16:44:39
#
#                                                     path  user_id  cohort_id  \
# 0                                                      /        1        8.0
# 1                                                java-ii        1        8.0
# 2                    java-ii/object-oriented-programming        1        8.0
# 3                     slides/object_oriented_programming        1        8.0
# 4                              javascript-i/conditionals        2       22.0
# ...                                                  ...      ...        ...
# 847325                              jquery/personal-site       64       28.0
# 847326                                 jquery/mapbox-api       64       28.0
# 847327                           jquery/ajax/weather-map       64       28.0
# 847328  anomaly-detection/discrete-probabilistic-methods      744       28.0
# 847329                                 jquery/mapbox-api       64       28.0
#
#         program_id             ip     name     slack  start_date    end_date  \
# 0                1   97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 1                1   97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 2                1   97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 3                1   97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 4                2   97.105.19.61    Teddy    #teddy  2018-01-08  2018-05-17
# ...            ...            ...      ...       ...         ...         ...
# 847325           2  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 847326           2  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 847327           2  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 847328           2  24.160.137.86    Staff         #  2014-02-04  2014-02-04
# 847329           2  71.150.217.33    Staff         #  2014-02-04  2014-02-04
#
#                  created_at           updated_at
# 0       2016-06-14 19:52:26  2016-06-14 19:52:26
# 1       2016-06-14 19:52:26  2016-06-14 19:52:26
# 2       2016-06-14 19:52:26  2016-06-14 19:52:26
# 3       2016-06-14 19:52:26  2016-06-14 19:52:26
# 4       2018-01-08 13:59:10  2018-01-08 13:59:10
# ...                     ...                  ...
# 847325  2018-12-06 17:04:19  2018-12-06 17:04:19
# 847326  2018-12-06 17:04:19  2018-12-06 17:04:19
# 847327  2018-12-06 17:04:19  2018-12-06 17:04:19
# 847328  2018-12-06 17:04:19  2018-12-06 17:04:19
# 847329  2018-12-06 17:04:19  2018-12-06 17:04:19
#
# [847330 rows x 13 columns]

# %%
# preliminary

conditions = [df.program_id == 1, df.program_id == 2, df.program_id == 3, df.program_id == 4]
result = ['web_dev','web_dev','data_science','web_dev']
df['program'] = np.select(conditions, result)
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name     slack  start_date  \
# 0        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 1        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 2        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 3        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 4       22.0           2  97.105.19.61    Teddy    #teddy  2018-01-08
#
#      end_date           created_at           updated_at  program
# 0  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 1  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 2  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 3  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 4  2018-05-17  2018-01-08 13:59:10  2018-01-08 13:59:10  web_dev

# %%
df.name
# Out:
# 0         Hampton
# 1         Hampton
# 2         Hampton
# 3         Hampton
# 4           Teddy
#            ...
# 847325      Staff
# 847326      Staff
# 847327      Staff
# 847328      Staff
# 847329      Staff
# Name: name, Length: 847330, dtype: object

# %%
df_wd = df[df.program == 'web_dev']
df_wd.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name     slack  start_date  \
# 0        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 1        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 2        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 3        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 4       22.0           2  97.105.19.61    Teddy    #teddy  2018-01-08
#
#      end_date           created_at           updated_at  program
# 0  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 1  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 2  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 3  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 4  2018-05-17  2018-01-08 13:59:10  2018-01-08 13:59:10  web_dev

# %%
df_wd.shape
# Out:
# (743918, 14)

# %%
#pulled from kan - good code for framing my head
df_wd_lesson_count = df_wd.groupby(by=['path'])[['user_id']].agg('count').sort_values('user_id', ascending=False)[1:60].reset_index()
df_wd_lesson_count.head(60)
# Out:
#                                                  path  user_id
# 0                                        javascript-i    18193
# 1                                                 toc    17580
# 2                            search/search_index.json    15331
# 3                                            java-iii    13162
# 4                                            html-css    13111
# 5                                             java-ii    12173
# 6                                              spring    11877
# 7                                              jquery    11037
# 8                                               mysql    10602
# 9                                              java-i    10460
# 10                                      javascript-ii    10290
# 11                                           appendix     8057
# 12  javascript-i/introduction/working-with-data-ty...     7326
# 13                                       mysql/tables     7101
# 14                             javascript-i/functions     7070
# 15                  javascript-i/javascript-with-html     7049
# 16                                  html-css/elements     6722
# 17                                    mysql/databases     6654
# 18                              java-iii/jsp-and-jstl     6601
# 19                                  java-iii/servlets     6518
# 20                                 javascript-i/loops     6455
# 21              html-css/css-ii/bootstrap-grid-system     6422
# 22                          javascript-i/conditionals     6329
# 23                                        mysql/users     6178
# 24                  java-i/syntax-types-and-variables     6016
# 25                java-ii/object-oriented-programming     6013
# 26                             mysql/basic-statements     6008
# 27             html-css/css-ii/bootstrap-introduction     5964
# 28                          spring/fundamentals/views     5695
# 29                                     html-css/forms     5610
# 30                   spring/fundamentals/repositories     5562
# 31                        java-i/introduction-to-java     5385
# 32                                     java-ii/arrays     5371
# 33                             javascript-ii/promises     5210
# 34                   javascript-i/arrays/manipulating     5209
# 35                                   jquery/selectors     5208
# 36                                      java-iii/jdbc     5170
# 37                               javascript-i/objects     5152
# 38                                     java-i/methods     5063
# 39               java-ii/inheritance-and-polymorphism     5059
# 40                    spring/fundamentals/controllers     5042
# 41                                java-ii/collections     5039
# 42                       javascript-i/bom-and-dom/dom     5012
# 43            java-ii/interfaces-and-abstract-classes     5006
# 44            html-css/css-i/selectors-and-properties     4986
# 45                javascript-i/introduction/operators     4957
# 46                                javascript-i/arrays     4938
# 47                            jquery/ajax/weather-map     4926
# 48                                 mysql/introduction     4849
# 49                         html-css/css-i/positioning     4670
# 50                                  java-i/console-io     4630
# 51                             javascript-ii/ajax-api     4530
# 52                      html-css/css-ii/media-queries     4529
# 53          javascript-i/introduction/primitive-types     4512
# 54                                  javascript-ii/es6     4492
# 55                                       java-iii/mvc     4476
# 56                java-i/control-statements-and-loops     4409
# 57                           html-css/css-i/box-model     4409
# 58                                       spring/setup     4404

# %%
# What do we need to prepare???
    # define by lesson (web_dev or DS) - that is offered now * 
    # split path id 
    # how many class mates per cohort (index) - might be useful
    # split df into two * 
    # drop staff *
    # nulls? *
    # drop update_at column

# %%
# 1 null
df.isnull().sum()
# Out:
# date          0
# time          0
# path          1
# user_id       0
# cohort_id     0
# program_id    0
# ip            0
# name          0
# slack         0
# start_date    0
# end_date      0
# created_at    0
# updated_at    0
# program       0
# dtype: int64

# %%
df.shape
# Out:
# (847330, 14)

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (847329, 14)

# %%
df.updated_at.sort_values
# Out:
# <bound method Series.sort_values of 0         2016-06-14 19:52:26
# 1         2016-06-14 19:52:26
# 2         2016-06-14 19:52:26
# 3         2016-06-14 19:52:26
# 4         2018-01-08 13:59:10
#                  ...
# 847325    2018-12-06 17:04:19
# 847326    2018-12-06 17:04:19
# 847327    2018-12-06 17:04:19
# 847328    2018-12-06 17:04:19
# 847329    2018-12-06 17:04:19
# Name: updated_at, Length: 847329, dtype: object>

# %%
df['url'] = df['path'].str.split('/').str[0]
df['url'].value_counts().head(50)

#lets see this after dropping staff - there might be certain pages only staff sees
# Out:
# javascript-i                  113838
# html-css                       81490
# mysql                          79416
# jquery                         58317
# spring                         55481
# java-iii                       54564
# java-ii                        52925
#                                45854
# java-i                         39644
# javascript-ii                  37477
# appendix                       35599
# toc                            17591
# search                         17539
# examples                       14169
# classification                 11453
# fundamentals                   11127
# 1-fundamentals                  9970
# content                         9102
# sql                             9035
# 3-sql                           7408
# slides                          7319
# python                          6718
# 6-regression                    5845
# 4-python                        5788
# 5-stats                         3984
# stats                           3936
# regression                      3828
# 7-classification                3706
# 10-anomaly-detection            3516
# clustering                      2850
# capstone                        2849
# anomaly-detection               2827
# 8-clustering                    2515
# 11-nlp                          2250
# storytelling                    2195
# 9-timeseries                    2177
# 2-storytelling                  2116
# web-design                      2103
# timeseries                      2080
# mkdocs                          1866
# index.html                      1723
# nlp                             1602
# 12-distributed-ml               1231
# 13-advanced-topics              1135
# prework                          899
# distributed-ml                   776
# advanced-topics                  304
# Intro_to_Regression_Module       268
# 1._Fundamentals                  243
# 5-regression                     228
# Name: url, dtype: int64

# %%
df.shape
# 847329
# Out:
# (847329, 15)

# %%
df = df[df['name'] != 'Staff']
df.shape
#763298
# Out:
# (763298, 15)

# %%
df['url'] = df['path'].str.split('/').str[0]
df['url'].value_counts()
# Out:
# javascript-i                   107537
# html-css                        76168
# mysql                           73741
# jquery                          54084
# spring                          49915
#                                 ...
# console-io                          1
# 6.01.03_Summarize                   1
# 4.2-compare-means                   1
# curie-statistics-assessment         1
# 6.03_Explore                        1
# Name: url, Length: 471, dtype: int64

# %%
#split program
df_wd = df[df.program == 'web_dev']
df_ds = df[df.program == 'data_science']

# %%
df_wd.shape, df_ds.shape
# Out:
# ((659887, 15), (103411, 15))

# %%
# look at path split column by datascience as I know this and it is smaller 
df_ds['url'].value_counts()
#153
# Out:
# fundamentals              8746
# classification            8620
#                           8358
# 1-fundamentals            7945
# sql                       7505
#                           ...
# misleading3_deaths.jpg       1
# .gitignore                   1
# Index.html                   1
# index.html                   1
# 7.4.1-pandas-overview        1
# Name: url, Length: 153, dtype: int64

# %%
df_ds['url'].value_counts(normalize = True)
#we can look at percent - 
# this is for question 1
# Out:
# fundamentals              0.084575
# classification            0.083357
#                           0.080823
# 1-fundamentals            0.076829
# sql                       0.072574
#                             ...
# misleading3_deaths.jpg    0.000010
# .gitignore                0.000010
# Index.html                0.000010
# index.html                0.000010
# 7.4.1-pandas-overview     0.000010
# Name: url, Length: 153, dtype: float64

# %%
df_ds['url'].value_counts().loc[lambda x : x>100] 
# 29 values above 100 hits

#### WE CAN GROUP THESE BY SIMILAR WORDS - Mangeable and scratches 124 values that are likely outliers
# Out:
# fundamentals            8746
# classification          8620
#                         8358
# 1-fundamentals          7945
# sql                     7505
# 3-sql                   6165
# python                  5599
# 4-python                4856
# 6-regression            4562
# appendix                3944
# 5-stats                 3361
# stats                   3299
# 7-classification        3220
# regression              2945
# search                  2206
# clustering              2191
# 10-anomaly-detection    2185
# anomaly-detection       2147
# 8-clustering            2081
# 11-nlp                  1865
# 9-timeseries            1723
# storytelling            1685
# 2-storytelling          1627
# timeseries              1592
# nlp                     1343
# 13-advanced-topics      1011
# 12-distributed-ml        996
# distributed-ml           659
# advanced-topics          267
# Name: url, dtype: int64

# %%
#make variable
ds_hits = df_ds['url'].value_counts().loc[lambda x : x>100] 
ds_hits.head(30)
# Out:
# fundamentals            8746
# classification          8620
#                         8358
# 1-fundamentals          7945
# sql                     7505
# 3-sql                   6165
# python                  5599
# 4-python                4856
# 6-regression            4562
# appendix                3944
# 5-stats                 3361
# stats                   3299
# 7-classification        3220
# regression              2945
# search                  2206
# clustering              2191
# 10-anomaly-detection    2185
# anomaly-detection       2147
# 8-clustering            2081
# 11-nlp                  1865
# 9-timeseries            1723
# storytelling            1685
# 2-storytelling          1627
# timeseries              1592
# nlp                     1343
# 13-advanced-topics      1011
# 12-distributed-ml        996
# distributed-ml           659
# advanced-topics          267
# Name: url, dtype: int64

# %%
ds_hits = pd.DataFrame(ds_hits)
ds_hits
# Out:
#                        url
# fundamentals          8746
# classification        8620
#                       8358
# 1-fundamentals        7945
# sql                   7505
# 3-sql                 6165
# python                5599
# 4-python              4856
# 6-regression          4562
# appendix              3944
# 5-stats               3361
# stats                 3299
# 7-classification      3220
# regression            2945
# search                2206
# clustering            2191
# 10-anomaly-detection  2185
# anomaly-detection     2147
# 8-clustering          2081
# 11-nlp                1865
# 9-timeseries          1723
# storytelling          1685
# 2-storytelling        1627
# timeseries            1592
# nlp                   1343
# 13-advanced-topics    1011
# 12-distributed-ml      996
# distributed-ml         659
# advanced-topics        267

# %%
#sets limit to 30 so i can see all
pd.set_option('display.max_rows', 30)
ds_hits
# Out:
#                        url
# fundamentals          8746
# classification        8620
#                       8358
# 1-fundamentals        7945
# sql                   7505
# 3-sql                 6165
# python                5599
# 4-python              4856
# 6-regression          4562
# appendix              3944
# 5-stats               3361
# stats                 3299
# 7-classification      3220
# regression            2945
# search                2206
# clustering            2191
# 10-anomaly-detection  2185
# anomaly-detection     2147
# 8-clustering          2081
# 11-nlp                1865
# 9-timeseries          1723
# storytelling          1685
# 2-storytelling        1627
# timeseries            1592
# nlp                   1343
# 13-advanced-topics    1011
# 12-distributed-ml      996
# distributed-ml         659
# advanced-topics        267

# %%
ds_hits['url'].astype(int)
# Out:
# fundamentals            8746
# classification          8620
#                         8358
# 1-fundamentals          7945
# sql                     7505
# 3-sql                   6165
# python                  5599
# 4-python                4856
# 6-regression            4562
# appendix                3944
# 5-stats                 3361
# stats                   3299
# 7-classification        3220
# regression              2945
# search                  2206
# clustering              2191
# 10-anomaly-detection    2185
# anomaly-detection       2147
# 8-clustering            2081
# 11-nlp                  1865
# 9-timeseries            1723
# storytelling            1685
# 2-storytelling          1627
# timeseries              1592
# nlp                     1343
# 13-advanced-topics      1011
# 12-distributed-ml        996
# distributed-ml           659
# advanced-topics          267
# Name: url, dtype: int64

# %%
# .replace isn't working for merging these rows, need to think of an alternative but moving on for now

ds_hits['url'] = ds_hits['url'].replace(['fundamentals', '1-fundamentals'], 'fundamentals')
ds_hits
# Out:
#                        url
# fundamentals          8746
# classification        8620
#                       8358
# 1-fundamentals        7945
# sql                   7505
# 3-sql                 6165
# python                5599
# 4-python              4856
# 6-regression          4562
# appendix              3944
# 5-stats               3361
# stats                 3299
# 7-classification      3220
# regression            2945
# search                2206
# clustering            2191
# 10-anomaly-detection  2185
# anomaly-detection     2147
# 8-clustering          2081
# 11-nlp                1865
# 9-timeseries          1723
# storytelling          1685
# 2-storytelling        1627
# timeseries            1592
# nlp                   1343
# 13-advanced-topics    1011
# 12-distributed-ml      996
# distributed-ml         659
# advanced-topics        267

# %%
ds_hits
# Out:
#                        url
# fundamentals          8746
# classification        8620
#                       8358
# 1-fundamentals        7945
# sql                   7505
# 3-sql                 6165
# python                5599
# 4-python              4856
# 6-regression          4562
# appendix              3944
# 5-stats               3361
# stats                 3299
# 7-classification      3220
# regression            2945
# search                2206
# clustering            2191
# 10-anomaly-detection  2185
# anomaly-detection     2147
# 8-clustering          2081
# 11-nlp                1865
# 9-timeseries          1723
# storytelling          1685
# 2-storytelling        1627
# timeseries            1592
# nlp                   1343
# 13-advanced-topics    1011
# 12-distributed-ml      996
# distributed-ml         659
# advanced-topics        267

# %%
ds_hits.dtypes
# Out:
# url    int64
# dtype: object

# %%
ds_hits = pd.DataFrame(ds_hits)
ds_hits
# Out:
#                        url
# fundamentals          8746
# classification        8620
#                       8358
# 1-fundamentals        7945
# sql                   7505
# 3-sql                 6165
# python                5599
# 4-python              4856
# 6-regression          4562
# appendix              3944
# 5-stats               3361
# stats                 3299
# 7-classification      3220
# regression            2945
# search                2206
# clustering            2191
# 10-anomaly-detection  2185
# anomaly-detection     2147
# 8-clustering          2081
# 11-nlp                1865
# 9-timeseries          1723
# storytelling          1685
# 2-storytelling        1627
# timeseries            1592
# nlp                   1343
# 13-advanced-topics    1011
# 12-distributed-ml      996
# distributed-ml         659
# advanced-topics        267

# %%
######## lets take a look at Web Dev

# %%
df_wd.url
# Out:
# 0
# 1              java-ii
# 2              java-ii
# 3               slides
# 4         javascript-i
#               ...
# 847317          jquery
# 847318        html-css
# 847319        java-iii
# 847320        java-iii
# 847324    javascript-i
# Name: url, Length: 659887, dtype: object

# %%
df_wd['url'].value_counts().loc[lambda x : x>100]
#why isn't it give me a count
# Out:
# javascript-i      107525
# html-css           76142
# mysql              73732
# jquery             54080
# spring             49907
# java-iii           49810
# java-ii            48698
# java-i             37067
# javascript-ii      34823
#                    31156
# appendix           26787
# toc                16669
# search             13984
# examples           13640
# content             8683
# slides              7153
# capstone            2296
# web-design          1891
# mkdocs              1865
# index.html          1113
# prework              855
# 1-fundamentals       175
# assets               118
# Name: url, dtype: int64

# %%
df_wd['url'].value_counts().loc[lambda x : x>100].count()
# so we have 23 values over 100 for web dev - I can likely scratch under 1000 to bring to 20
# Out:
# 23

# %%
# this is what we need
wd_hits = df_wd['url'].value_counts().loc[lambda x : x>1000]
wd_hits = pd.DataFrame(wd_hits)
wd_hits
#change into a dataframe
#wd_hits = pd.DataFrame(wd_hits)
#see full list
pd.set_option('display.max_rows', 30)

# %%
wd_hits
# Out:
#                   url
# javascript-i   107525
# html-css        76142
# mysql           73732
# jquery          54080
# spring          49907
# java-iii        49810
# java-ii         48698
# java-i          37067
# javascript-ii   34823
#                 31156
# appendix        26787
# toc             16669
# search          13984
# examples        13640
# content          8683
# slides           7153
# capstone         2296
# web-design       1891
# mkdocs           1865
# index.html       1113

# %%
#prepare
#
conditions = [df.program_id == 1, df.program_id == 2, df.program_id == 3, df.program_id == 4]
result = ['web_dev','web_dev','data_science','web_dev']
df['program'] = np.select(conditions, result)
#drop na
df.dropna(inplace = True)
# eliminated staff from dataset
df = df[df['name'] != 'Staff']

#define main path for url
df['url'] = df['path'].str.split('/').str[0]

# creating subpath for page hits
df['subpath'] = df.path.apply(lambda x: x.split('/'))

# split programs into two datasets - this one last in prepare
df_wd = df[df.program == 'web_dev']
df_ds = df[df.program == 'data_science']

# %%
df.path
# Out:
# 0                                             /
# 1                                       java-ii
# 2           java-ii/object-oriented-programming
# 3            slides/object_oriented_programming
# 4                     javascript-i/conditionals
#                           ...
# 847317                     jquery/personal-site
# 847318    html-css/css-ii/bootstrap-grid-system
# 847319                                 java-iii
# 847320                        java-iii/servlets
# 847324             javascript-i/bom-and-dom/dom
# Name: path, Length: 763298, dtype: object

# %%
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name     slack  start_date  \
# 0        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 1        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 2        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 3        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 4       22.0           2  97.105.19.61    Teddy    #teddy  2018-01-08
#
#      end_date           created_at           updated_at  program           url
# 0  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 1  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev       java-ii
# 2  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev       java-ii
# 3  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev        slides
# 4  2018-05-17  2018-01-08 13:59:10  2018-01-08 13:59:10  web_dev  javascript-i

# %% [markdown]
# ## 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
df['subpath'] = df.path.apply(lambda x: x.split('/'))

# %%
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name     slack  start_date  \
# 0        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 1        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 2        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 3        8.0           1  97.105.19.61  Hampton  #hampton  2015-09-22
# 4       22.0           2  97.105.19.61    Teddy    #teddy  2018-01-08
#
#      end_date           created_at           updated_at  program  \
# 0  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 1  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 2  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 3  2016-02-06  2016-06-14 19:52:26  2016-06-14 19:52:26  web_dev
# 4  2018-05-17  2018-01-08 13:59:10  2018-01-08 13:59:10  web_dev
#
#             url                                 subpath
# 0                                                  [, ]
# 1       java-ii                               [java-ii]
# 2       java-ii  [java-ii, object-oriented-programming]
# 3        slides   [slides, object_oriented_programming]
# 4  javascript-i            [javascript-i, conditionals]

# %%
df_ds.groupby('name')['url','user_id'].nunique()
# Out:
#           url  user_id
# name
# Bayes      86       23
# Curie      55       21
# Darden     74       29
# Easley     38       17
# Florence   42       21

# %%
pd.set_option('display.max_rows', 41)

df_wd.groupby('name')['url','user_id'].nunique()
# Out:
#             url  user_id
# name
# Andromeda    41       28
# Apex         28       24
# Apollo        2        1
# Arches       35       18
# Badlands      8        3
# Bash         39       23
# Betelgeuse   36       22
# Ceres        40       29
# Deimos       38       27
# Denali        3        1
# Europa       36       28
# Everglades    1        1
# Fortuna      28       29
# Franklin     23        2
# Ganymede     41       29
# Glacier      17        6
# Hampton      39        5
# Hyperion     38       23
# Ike          17        5
# Joshua       11        5
# Jupiter      43       33
# Kalypso      40       23
# Kings        18       10
# Lassen       52       13
# Luna         33       20
# Mammoth      20        5
# Marco        30       31
# Neptune      24       37
# Niagara      19        8
# Oberon       13       26
# Olympic      22       14
# Pinnacles    30       14
# Quincy       23       17
# Sequoia      33       28
# Teddy        81       35
# Ulysses      34       33
# Voyageurs    81       34
# Wrangell    177       26
# Xanadu       31       20
# Yosemite     45       29
# Zion         70       25

# %%
df_wd.groupby('name')['path'].count()
# Out:
# name
# Andromeda    25359
# Apex         33568
# Apollo           5
# Arches        8890
# Badlands        93
#              ...
# Voyageurs    35636
# Wrangell     25586
# Xanadu       27749
# Yosemite     20743
# Zion         38096
# Name: path, Length: 41, dtype: int64

# %%
df.path.value_counts()
# Out:
# /                             39514
# toc                           16680
# javascript-i                  16386
# search/search_index.json      16185
# html-css                      11843
#                               ...
# About_NLP                         1
# 8.0_Intro_Module                  1
# introduction-to-matplotlib        1
# 2.0_Intro_Stats                   1
# 13.5_Tableau                      1
# Name: path, Length: 1844, dtype: int64

# %%
df.url.value_counts()
# Out:
# javascript-i                   107537
# html-css                        76168
# mysql                           73741
# jquery                          54084
# spring                          49915
#                                 ...
# console-io                          1
# 6.01.03_Summarize                   1
# 4.2-compare-means                   1
# curie-statistics-assessment         1
# 6.03_Explore                        1
# Name: url, Length: 471, dtype: int64
