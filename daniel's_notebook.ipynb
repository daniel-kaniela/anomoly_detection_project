# %% [markdown]
# ### Questions for Board Meeting
# ### MVP
# - 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?
# - 2. Which lessons are least accessed?
# - 3. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?
# - 4. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
# - 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?

# %% [markdown]
# ### Followup quesitons
#
# - 1. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
# - 2. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns
import env
import os

from env import host, user, password

# DBSCAN import
from sklearn.cluster import DBSCAN

# Scaler import
from sklearn.preprocessing import MinMaxScaler

import acquire
import prepare

# %%
#acquire sql query
df = acquire.acquire()

# %%
# see prepare for cleaning
df = prepare.clean_cohort(df)

# %%
# splits our df into a webdev and data science
df_wd, df_ds = prepare.program_split(df)

# %%
df_wd['url'].value_counts()
# Out:
# javascript-i                            107525
# html-css                                 76142
# mysql                                    73732
# jquery                                   54080
# spring                                   49907
#                                          ...
# 10.03_Explore                                1
# 10.04.01_FeatureExtraction_FreqBased         1
# 10.04.02_FeatureExtraction_Word2Vec          1
# 10.04.03_SentimentAnalysis                   1
# selectors                                    1
# Name: url, Length: 360, dtype: int64

# %%
wd_hits = df_wd['url'].value_counts().loc[lambda x : x>100]

# %%
# pulled from Kan - will throw into prepare
df_ds['lesson'] = np.where(df_ds.path.str.contains('appendix'), 'appendix',
np.where(df_ds.path.str.contains('search'), 'search',
np.where(df_ds.path.str.contains('classification'),'classification',
np.where(df_ds.path.str.contains('sql'), 'sql',
np.where(df_ds.path.str.contains('fundamentals'), 'fundamentals',
np.where(df_ds.path.str.contains('regression'), 'regression',
np.where(df_ds.path.str.contains('python'), 'python',
np.where(df_ds.path.str.contains('stats'), 'stats', 
np.where(df_ds.path.str.contains('anomaly'), 'anomaly',
np.where(df_ds.path.str.contains('clustering'), 'clustering',
np.where(df_ds.path.str.contains('nlp'), 'nlp',
np.where(df_ds.path.str.contains('timeseries'), 'time_series',
np.where(df_ds.path.str.contains('distributed-ml'), 'distributed_ml''',
np.where(df_ds.path.str.contains('storytelling'), 'storytelling',

np.where(df_ds.path.str.contains('advanced-topics'), 'advanced-topics',
np.where(df_ds.path.str.contains('capstones'), 'capstones',
'pending'))))))))))))))))
df_ds.lesson.unique()
# Out:
# array(['pending', 'sql', 'storytelling', 'appendix', 'fundamentals',
#        'search', 'advanced-topics', 'regression', 'anomaly', 'nlp',
#        'classification', 'clustering', 'time_series', 'stats', 'python',
#        'distributed_ml', 'capstones'], dtype=object)

# %%
# pulled from Kan - will throw into prepare
df_ds['url2'] = np.where(df_ds.url.str.contains('appendix'), 'appendix',
np.where(df_ds.url.str.contains('search'), 'search',
np.where(df_ds.url.str.contains('classification'),'classification',
np.where(df_ds.url.str.contains('sql'), 'sql',
np.where(df_ds.url.str.contains('fundamentals'), 'fundamentals',
np.where(df_ds.url.str.contains('regression'), 'regression',
np.where(df_ds.url.str.contains('python'), 'python',
np.where(df_ds.url.str.contains('stats'), 'stats', 
np.where(df_ds.url.str.contains('anomaly'), 'anomaly',
np.where(df_ds.url.str.contains('clustering'), 'clustering',
np.where(df_ds.url.str.contains('nlp'), 'nlp',
np.where(df_ds.url.str.contains('timeseries'), 'time_series',
np.where(df_ds.url.str.contains('distributed-ml'), 'distributed_ml''',
np.where(df_ds.url.str.contains('storytelling'), 'storytelling',

np.where(df_ds.url.str.contains('advanced-topics'), 'advanced-topics',
np.where(df_ds.url.str.contains('capstones'), 'capstones',
'pending'))))))))))))))))
df_ds.url2.unique()
# Out:
# array(['pending', 'sql', 'storytelling', 'appendix', 'fundamentals',
#        'search', 'advanced-topics', 'regression', 'anomaly', 'nlp',
#        'classification', 'clustering', 'time_series', 'stats', 'python',
#        'distributed_ml', 'capstones'], dtype=object)

# %%
df_ds[['url', 'url2']].value_counts()
# Out:
# url                          url2
# fundamentals                 fundamentals      8746
# classification               classification    8620
#                              pending           8358
# 1-fundamentals               fundamentals      7945
# sql                          sql               7505
#                                                ...
# index.html                   pending              1
# imports                      pending              1
# group-by                     pending              1
# 7.4.2-series                 pending              1
# 5-detecting-with-clustering  clustering           1
# Length: 153, dtype: int64

# %%
# created lesson column with values for web dev lessons
df_wd['lesson'] = np.where(df_wd.path.str.contains('search'),'search',
np.where(df_wd.path.str.contains('index'),'index',
np.where(df_wd.path.str.contains('javascript'),'javascript',
np.where(df_wd.path.str.contains('toc'),'toc',
np.where(df_wd.path.str.contains('java'),'java',
np.where(df_wd.path.str.contains('html|css'),'html-css',
np.where(df_wd.path.str.contains('spring'),'spring',
np.where(df_wd.path.str.contains('jquery'),'jquery',
np.where(df_wd.path.str.contains('mysql'),'mysql',
np.where(df_wd.path.str.contains('capstone'),'capstone',
np.where(df_wd.path.str.contains('array|syntax|object_oriented|polymorph|methods|collections|deployment'),'structure',
np.where(df_wd.path.str.contains('php'),'php',
np.where(df_wd.path.str.contains('larvel'),'larvel',
         
'pending')))))))))))))
                                                                                                                                                
df_wd.lesson.unique()
# Out:
# array(['pending', 'java', 'structure', 'javascript', 'search', 'spring',
#        'capstone', 'index', 'html-css', 'mysql', 'jquery', 'php', 'toc'],
#       dtype=object)

# %%
##### so with this our data should be set

# %% [markdown]
# ### 4. What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %%
### datetime - check timestamps min, max - make dfs that are hits beyond enddate -
### compare those dates by value_counts() look to see if there is anythign interesting

# %%
#datetime to end_date
df_wd.end_date = pd.to_datetime(df.end_date)
df_ds.end_date = pd.to_datetime(df.end_date)

# %%
#checking timeframe for web_dev
df_wd.end_date.min(), df_wd.end_date.max()
# Out:
# (Timestamp('2014-04-22 00:00:00'), Timestamp('2021-10-01 00:00:00'))

# %%
#checking timeframe for datascience
df_ds.end_date.min(), df_ds.end_date.max()
# Out:
# (Timestamp('2020-01-30 00:00:00'), Timestamp('2021-09-03 00:00:00'))

# %%
# add to prepare.py
df_wd['datetime'] = df_wd.date
df_wd['datetime'] = pd.to_datetime(df_wd['datetime'])

# %%
df_ds['datetime'] = df_ds.date
df_ds['datetime'] = pd.to_datetime(df_ds['datetime'])

# %%
#making a dataframe for each 
wd_diff_time = df_wd[df_wd.datetime > df_wd.end_date][['path', 'user_id', 'end_date', 'datetime', 'url', 'lesson']]
ds_diff_time = df_ds[df_ds.datetime > df_ds.end_date][['path', 'user_id', 'end_date', 'datetime', 'url', 'lesson']]

# %%
pd.DataFrame(ds_diff_time['path'].value_counts(ascending = False)).head(10)
# Out:
#                                                 path
# /                                               1436
# search/search_index.json                         493
# sql/mysql-overview                               275
# classification/overview                          266
# classification/scale_features_or_not.svg         219
# anomaly-detection/AnomalyDetectionCartoon.jpeg   193
# anomaly-detection/overview                       191
# fundamentals/AI-ML-DL-timeline.jpg               189
# fundamentals/modern-data-scientist.jpg           187
# fundamentals/intro-to-data-science               184

# %%
# top lessons Data Science alumni reference
pd.DataFrame(ds_diff_time['lesson'].value_counts(ascending = False)).head(4)
# Out:
#                 lesson
# sql               1555
# fundamentals      1514
# pending           1472
# classification    1312

# %%
# top lessons Web Dev alumni reference
pd.DataFrame(wd_diff_time['lesson'].value_counts(ascending = False)).head(4)
# Out:
#             lesson
# java         20304
# javascript   19794
# pending      15290
# html-css     13914

# %% [markdown]
# ### 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?

# %%
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name  start_date    end_date  \
# 0        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0           2  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at  program           url  \
# 0  2016-06-14 19:52:26  web_dev
# 1  2016-06-14 19:52:26  web_dev       java-ii
# 2  2016-06-14 19:52:26  web_dev       java-ii
# 3  2016-06-14 19:52:26  web_dev        slides
# 4  2018-01-08 13:59:10  web_dev  javascript-i
#
#                                   subpath  counter
# 0                                    [, ]        1
# 1                               [java-ii]        1
# 2  [java-ii, object-oriented-programming]        1
# 3   [slides, object_oriented_programming]        1
# 4            [javascript-i, conditionals]        1

# %%
# set datetime
df_ds.date = pd.to_datetime(df_ds.date)

# %%
#set index
df_ds =df_ds.set_index('date')

# %%
#locaiton of 2019
ds_2019 = df_ds.loc['2019']

#20,000 values
## next how do we search? maybe by top hits?

# %%
# why do we just have bays?
ds_2019['name'].value_counts()
# Out:
# Bayes    20068
# Name: name, dtype: int64

# %%
# okay so we don't have ada (didn't notice until now) - Bayes was 2019 hence why it is the only one showing
df_ds['name'].value_counts()
# Out:
# Darden      32015
# Bayes       26538
# Curie       21581
# Easley      14715
# Florence     8562
# Name: name, dtype: int64

# %%
ds_2019.head()

# java	20304
# javascript	19794
# pending	15290
# html-css	13914
# Out:
#                 time path  user_id  cohort_id  program_id            ip  \
# date
# 2019-08-20  09:39:58    /      466       34.0           3  97.105.19.58
# 2019-08-20  09:39:59    /      467       34.0           3  97.105.19.58
# 2019-08-20  09:39:59    /      468       34.0           3  97.105.19.58
# 2019-08-20  09:40:02    /      469       34.0           3  97.105.19.58
# 2019-08-20  09:40:08    /      470       34.0           3  97.105.19.58
#
#              name  start_date   end_date           created_at       program  \
# date
# 2019-08-20  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55  data_science
# 2019-08-20  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55  data_science
# 2019-08-20  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55  data_science
# 2019-08-20  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55  data_science
# 2019-08-20  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55  data_science
#
#            url subpath  counter   lesson     url2   datetime
# date
# 2019-08-20        [, ]        1  pending  pending 2019-08-20
# 2019-08-20        [, ]        1  pending  pending 2019-08-20
# 2019-08-20        [, ]        1  pending  pending 2019-08-20
# 2019-08-20        [, ]        1  pending  pending 2019-08-20
# 2019-08-20        [, ]        1  pending  pending 2019-08-20

# %%
#don't know if this solves issues
ds_2019 = ds_2019.reset_index()

# %%
# I don't see anything for the data science students looking at webdev curriculum in 2019
ds_2019.lesson.value_counts()
# Out:
# fundamentals       2558
# python             2183
# regression         2106
# sql                1913
# stats              1678
# classification     1557
# pending            1456
# clustering         1115
# appendix           1105
# nlp                 951
# time_series         948
# anomaly             910
# storytelling        757
# distributed_ml      428
# search              338
# advanced-topics      64
# capstones             1
# Name: lesson, dtype: int64

# %%
#look at web_dev
#following previous code but with wd
df_wd.date = pd.to_datetime(df_wd.date)

df_wd =df_wd.set_index('date')

wd_2019 = df_wd.loc['2019']

# %%
#alot bigger of a list than ds
wd_2019['name'].value_counts()
# Out:
# Ceres         36472
# Zion          36290
# Betelgeuse    27220
# Andromeda     22768
# Deimos        16927
# Yosemite      11130
# Europa         8735
# Xanadu         7828
# Lassen         3168
# Olympic        3074
# Ulysses        1875
# Voyageurs      1533
# Wrangell       1003
# Sequoia         939
# Teddy           922
# Kings           596
# Quincy          289
# Pinnacles       216
# Glacier         186
# Arches          148
# Ike             125
# Mammoth         111
# Niagara          66
# Joshua           40
# Badlands         16
# Franklin         14
# Name: name, dtype: int64

# %%
# top hits from DS alumni - starting point
# sql	1555
# fundamentals	1514
# pending	1472
# classification	1312

# %%
wd_2019.lesson.value_counts()
# I see mysql hits and potentially 'pending' but it applies to both
# Out:
# javascript    42064
# java          36860
# html-css      29070
# mysql         20217
# spring        14644
# jquery        13823
# pending       13802
# toc            4730
# search         3897
# index          1149
# capstone        873
# php             471
# structure        91
# Name: lesson, dtype: int64

# %%
wd_2019_sql = wd_2019[wd_2019.lesson == 'mysql']
wd_2019_sql.tail(40)
# Out:
#                 time                       path  user_id  cohort_id  \
# date
# 2019-12-28  10:43:43        mysql/clauses/limit      488       51.0
# 2019-12-28  14:01:44                      mysql      456       33.0
# 2019-12-28  14:01:47         mysql/introduction      456       33.0
# 2019-12-28  15:05:46                      mysql      510       51.0
# 2019-12-28  15:07:42        mysql/relationships      510       51.0
# 2019-12-28  15:07:51  mysql/relationships/joins      510       51.0
# 2019-12-28  16:44:11                      mysql      433       33.0
# 2019-12-30  08:11:54            mysql//intellij      505       51.0
# 2019-12-30  08:11:55      mysql/img/favicon.ico      505       51.0
# 2019-12-30  08:12:12     mysql//extra-exercises      505       51.0
# 2019-12-30  08:12:54            mysql//intellij      505       51.0
# 2019-12-30  08:12:57            mysql//intellij      505       51.0
# 2019-12-30  11:10:00  mysql/relationships/joins      488       51.0
# 2019-12-30  11:10:29        mysql/relationships      488       51.0
# 2019-12-30  11:10:31              mysql/aliases      488       51.0
# 2019-12-30  11:10:37             mysql/group-by      488       51.0
# 2019-12-30  11:10:42            mysql/functions      488       51.0
# 2019-12-30  11:10:48        mysql/clauses/limit      488       51.0
# 2019-12-30  11:10:55     mysql/clauses/order-by      488       51.0
# 2019-12-30  11:10:59        mysql/clauses/where      488       51.0
# 2019-12-30  11:11:10              mysql/clauses      488       51.0
# 2019-12-30  11:11:12             mysql/intellij      488       51.0
# 2019-12-30  11:16:24              mysql/clauses      488       51.0
# 2019-12-30  11:16:25        mysql/clauses/where      488       51.0
# 2019-12-30  20:44:54                      mysql      509       51.0
# 2019-12-30  20:44:56      mysql/database-design      509       51.0
# 2019-12-30  22:43:21                      mysql      201       24.0
# 2019-12-30  22:43:28            mysql/functions      201       24.0
# 2019-12-30  22:43:30             mysql/group-by      201       24.0
# 2019-12-30  22:43:34     mysql/basic-statements      201       24.0
# 2019-12-30  22:43:35      mysql/sample-database      201       24.0
# 2019-12-30  22:43:38  mysql/relationships/joins      201       24.0
# 2019-12-31  07:30:38                      mysql      489       51.0
# 2019-12-31  07:30:42                mysql/users      489       51.0
# 2019-12-31  07:30:47         mysql/introduction      489       51.0
# 2019-12-31  07:37:00            mysql/databases      489       51.0
# 2019-12-31  07:37:38                mysql/users      489       51.0
# 2019-12-31  07:39:50            mysql/databases      489       51.0
# 2019-12-31  07:41:53               mysql/tables      489       51.0
# 2019-12-31  09:08:28                      mysql      509       51.0
#
#             program_id               ip       name  start_date   end_date  \
# date
# 2019-12-28           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-28           2   107.136.68.158      Ceres  2019-07-15 2019-12-11
# 2019-12-28           2   107.136.68.158      Ceres  2019-07-15 2019-12-11
# 2019-12-28           2     24.243.7.150     Deimos  2019-09-16 2020-02-27
# 2019-12-28           2     24.243.7.150     Deimos  2019-09-16 2020-02-27
# 2019-12-28           2     24.243.7.150     Deimos  2019-09-16 2020-02-27
# 2019-12-28           2     70.94.181.28      Ceres  2019-07-15 2019-12-11
# 2019-12-30           2     45.21.32.233     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2     45.21.32.233     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2     45.21.32.233     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2     45.21.32.233     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2     45.21.32.233     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    99.100.172.39     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    108.71.183.46     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2    108.71.183.46     Deimos  2019-09-16 2020-02-27
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-30           2  173.174.211.244  Voyageurs  2018-05-29 2018-10-11
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    66.25.173.125     Deimos  2019-09-16 2020-02-27
# 2019-12-31           2    108.71.183.46     Deimos  2019-09-16 2020-02-27
#
#                      created_at  program    url  \
# date
# 2019-12-28  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-28  2019-07-15 16:57:21  web_dev  mysql
# 2019-12-28  2019-07-15 16:57:21  web_dev  mysql
# 2019-12-28  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-28  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-28  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-28  2019-07-15 16:57:21  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-30  2018-05-25 22:25:57  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
# 2019-12-31  2019-09-16 13:07:04  web_dev  mysql
#
#                                   subpath  counter lesson   datetime
# date
# 2019-12-28        [mysql, clauses, limit]        1  mysql 2019-12-28
# 2019-12-28                        [mysql]        1  mysql 2019-12-28
# 2019-12-28          [mysql, introduction]        1  mysql 2019-12-28
# 2019-12-28                        [mysql]        1  mysql 2019-12-28
# 2019-12-28         [mysql, relationships]        1  mysql 2019-12-28
# 2019-12-28  [mysql, relationships, joins]        1  mysql 2019-12-28
# 2019-12-28                        [mysql]        1  mysql 2019-12-28
# 2019-12-30            [mysql, , intellij]        1  mysql 2019-12-30
# 2019-12-30      [mysql, img, favicon.ico]        1  mysql 2019-12-30
# 2019-12-30     [mysql, , extra-exercises]        1  mysql 2019-12-30
# 2019-12-30            [mysql, , intellij]        1  mysql 2019-12-30
# 2019-12-30            [mysql, , intellij]        1  mysql 2019-12-30
# 2019-12-30  [mysql, relationships, joins]        1  mysql 2019-12-30
# 2019-12-30         [mysql, relationships]        1  mysql 2019-12-30
# 2019-12-30               [mysql, aliases]        1  mysql 2019-12-30
# 2019-12-30              [mysql, group-by]        1  mysql 2019-12-30
# 2019-12-30             [mysql, functions]        1  mysql 2019-12-30
# 2019-12-30        [mysql, clauses, limit]        1  mysql 2019-12-30
# 2019-12-30     [mysql, clauses, order-by]        1  mysql 2019-12-30
# 2019-12-30        [mysql, clauses, where]        1  mysql 2019-12-30
# 2019-12-30               [mysql, clauses]        1  mysql 2019-12-30
# 2019-12-30              [mysql, intellij]        1  mysql 2019-12-30
# 2019-12-30               [mysql, clauses]        1  mysql 2019-12-30
# 2019-12-30        [mysql, clauses, where]        1  mysql 2019-12-30
# 2019-12-30                        [mysql]        1  mysql 2019-12-30
# 2019-12-30       [mysql, database-design]        1  mysql 2019-12-30
# 2019-12-30                        [mysql]        1  mysql 2019-12-30
# 2019-12-30             [mysql, functions]        1  mysql 2019-12-30
# 2019-12-30              [mysql, group-by]        1  mysql 2019-12-30
# 2019-12-30      [mysql, basic-statements]        1  mysql 2019-12-30
# 2019-12-30       [mysql, sample-database]        1  mysql 2019-12-30
# 2019-12-30  [mysql, relationships, joins]        1  mysql 2019-12-30
# 2019-12-31                        [mysql]        1  mysql 2019-12-31
# 2019-12-31                 [mysql, users]        1  mysql 2019-12-31
# 2019-12-31          [mysql, introduction]        1  mysql 2019-12-31
# 2019-12-31             [mysql, databases]        1  mysql 2019-12-31
# 2019-12-31                 [mysql, users]        1  mysql 2019-12-31
# 2019-12-31             [mysql, databases]        1  mysql 2019-12-31
# 2019-12-31                [mysql, tables]        1  mysql 2019-12-31
# 2019-12-31                        [mysql]        1  mysql 2019-12-31

# %%
# i see hits all the way to the last day of 2019 for the sql material
# lets double check it isn't in the Web dev curriculum

# %%
df_wd.lesson.value_counts()
# Out:
# javascript    149227
# java          138797
# html-css       92725
# mysql          71913
# pending        58516
# spring         52344
# jquery         50290
# toc            16669
# search         16000
# capstone        4834
# index           3587
# structure       2900
# php             2085
# Name: lesson, dtype: int64

# %%
# it might be lesson not giving results, lets try url

# %%
wd_2019.url.value_counts().head(25)
###
# Out:
# javascript-i               30618
# html-css                   24649
# mysql                      20779
# jquery                     14875
# spring                     14115
# java-ii                    13835
# java-iii                   11978
# java-i                     10401
# javascript-ii               9726
#                             7683
# appendix                    5896
# toc                         4730
# examples                    3983
# search                      3897
# content                     1745
# web-design                  1010
# index.html                   427
# prework                      179
# 1-fundamentals               158
# slides                       141
# assets                        79
# 1._Fundamentals               49
# 4-python                      49
# 3.0-mysql-overview            35
# study-session-with-ryan       26
# Name: url, dtype: int64

# %%
#12-22
wd_2019_url = wd_2019[wd_2019.url == '1-fundamentals']
wd_2019_url.tail(40)
# Out:
#                 time                                         path  user_id  \
# date
# 2019-10-15  13:56:32         1-fundamentals/AI-ML-DL-timeline.jpg      450
# 2019-10-17  15:58:40     1-fundamentals/1.1-intro-to-data-science      451
# 2019-10-17  15:58:40     1-fundamentals/modern-data-scientist.jpg      451
# 2019-10-17  15:58:40         1-fundamentals/AI-ML-DL-timeline.jpg      451
# 2019-10-25  01:46:43     1-fundamentals/1.1-intro-to-data-science      513
# 2019-10-25  01:46:46     1-fundamentals/modern-data-scientist.jpg      513
# 2019-10-25  01:46:47         1-fundamentals/AI-ML-DL-timeline.jpg      513
# 2019-10-25  12:58:53     1-fundamentals/1.1-intro-to-data-science      513
# 2019-10-25  12:58:54     1-fundamentals/modern-data-scientist.jpg      513
# 2019-10-25  12:58:54         1-fundamentals/AI-ML-DL-timeline.jpg      513
# 2019-10-31  22:49:44     1-fundamentals/1.1-intro-to-data-science      513
# 2019-10-31  22:53:43     1-fundamentals/modern-data-scientist.jpg      513
# 2019-10-31  22:53:44         1-fundamentals/AI-ML-DL-timeline.jpg      513
# 2019-11-09  18:05:35     1-fundamentals/1.1-intro-to-data-science      124
# 2019-11-09  18:05:36         1-fundamentals/AI-ML-DL-timeline.jpg      124
# 2019-11-09  18:05:36     1-fundamentals/modern-data-scientist.jpg      124
# 2019-11-09  18:13:51     1-fundamentals/1.1-intro-to-data-science      124
# 2019-11-09  18:13:51     1-fundamentals/modern-data-scientist.jpg      124
# 2019-11-09  18:13:51         1-fundamentals/AI-ML-DL-timeline.jpg      124
# 2019-11-12  14:25:20     1-fundamentals/1.1-intro-to-data-science      458
# 2019-11-12  14:25:20     1-fundamentals/modern-data-scientist.jpg      458
# 2019-11-12  14:25:20         1-fundamentals/AI-ML-DL-timeline.jpg      458
# 2019-11-12  14:25:24                  1-fundamentals/3-vocabulary      458
# 2019-11-30  01:12:39     1-fundamentals/1.1-intro-to-data-science      171
# 2019-11-30  01:12:40     1-fundamentals/modern-data-scientist.jpg      171
# 2019-11-30  01:12:40         1-fundamentals/AI-ML-DL-timeline.jpg      171
# 2019-12-05  00:45:04     1-fundamentals/1.1-intro-to-data-science       94
# 2019-12-05  00:45:04     1-fundamentals/modern-data-scientist.jpg       94
# 2019-12-05  00:45:04         1-fundamentals/AI-ML-DL-timeline.jpg       94
# 2019-12-05  09:22:08     1-fundamentals/1.1-intro-to-data-science       94
# 2019-12-05  09:22:09     1-fundamentals/modern-data-scientist.jpg       94
# 2019-12-05  09:22:09         1-fundamentals/AI-ML-DL-timeline.jpg       94
# 2019-12-22  19:41:44     1-fundamentals/1.2-data-science-pipeline       18
# 2019-12-22  19:41:44           1-fundamentals/DataToAction_v2.jpg       18
# 2019-12-22  19:42:23           1-fundamentals/2.2-excel-functions       18
# 2019-12-22  19:43:06  1-fundamentals/2.3-visualization-with-excel       18
# 2019-12-22  19:43:58             1-fundamentals/1.3-pipeline-demo       18
# 2019-12-22  19:44:37     1-fundamentals/1.2-data-science-pipeline       18
# 2019-12-22  19:44:37           1-fundamentals/DataToAction_v2.jpg       18
# 2019-12-22  19:44:44             1-fundamentals/1.3-pipeline-demo       18
#
#             cohort_id  program_id               ip     name  start_date  \
# date
# 2019-10-15       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-10-17       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-10-17       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-10-17       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-10-25        7.0           1  173.239.232.172  Glacier  2015-06-05
# 2019-10-25        7.0           1  173.239.232.172  Glacier  2015-06-05
# 2019-10-25        7.0           1  173.239.232.172  Glacier  2015-06-05
# 2019-10-25        7.0           1      74.81.88.18  Glacier  2015-06-05
# 2019-10-25        7.0           1      74.81.88.18  Glacier  2015-06-05
# 2019-10-25        7.0           1      74.81.88.18  Glacier  2015-06-05
# 2019-10-31        7.0           1    66.25.130.242  Glacier  2015-06-05
# 2019-10-31        7.0           1   205.251.151.18  Glacier  2015-06-05
# 2019-10-31        7.0           1   205.251.151.18  Glacier  2015-06-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-09       23.0           2    107.77.222.69  Ulysses  2018-03-05
# 2019-11-12       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-11-12       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-11-12       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-11-12       33.0           2     97.105.19.58    Ceres  2019-07-15
# 2019-11-30       23.0           2    70.94.162.244  Ulysses  2018-03-05
# 2019-11-30       23.0           2    70.94.162.244  Ulysses  2018-03-05
# 2019-11-30       23.0           2    70.94.162.244  Ulysses  2018-03-05
# 2019-12-05       19.0           1    108.78.170.79   Quincy  2017-06-05
# 2019-12-05       19.0           1    108.78.170.79   Quincy  2017-06-05
# 2019-12-05       19.0           1    108.78.170.79   Quincy  2017-06-05
# 2019-12-05       19.0           1  207.189.160.146   Quincy  2017-06-05
# 2019-12-05       19.0           1  207.189.160.146   Quincy  2017-06-05
# 2019-12-05       19.0           1  207.189.160.146   Quincy  2017-06-05
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
# 2019-12-22       22.0           2    45.20.117.182    Teddy  2018-01-08
#
#              end_date           created_at  program             url  \
# date
# 2019-10-15 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-10-17 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-10-17 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-10-17 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-25 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-31 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-31 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-10-31 2015-10-06  2016-06-14 19:52:26  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-09 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-12 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-11-12 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-11-12 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-11-12 2019-12-11  2019-07-15 16:57:21  web_dev  1-fundamentals
# 2019-11-30 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-30 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-11-30 2018-07-19  2018-03-05 14:22:11  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-05 2017-09-22  2017-06-05 20:12:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
# 2019-12-22 2018-05-17  2018-01-08 13:59:10  web_dev  1-fundamentals
#
#                                                    subpath  counter   lesson  \
# date
# 2019-10-15         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-10-17     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-10-17     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-10-17         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-10-25     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-10-25     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-10-25         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-10-25     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-10-25     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-10-25         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-10-31     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-10-31     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-10-31         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-11-09     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-11-09         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-11-09     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-11-09     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-11-09     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-11-09         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-11-12     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-11-12     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-11-12         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-11-12                  [1-fundamentals, 3-vocabulary]        1  pending
# 2019-11-30     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-11-30     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-11-30         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-12-05     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-12-05     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-12-05         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-12-05     [1-fundamentals, 1.1-intro-to-data-science]        1  pending
# 2019-12-05     [1-fundamentals, modern-data-scientist.jpg]        1  pending
# 2019-12-05         [1-fundamentals, AI-ML-DL-timeline.jpg]        1  pending
# 2019-12-22     [1-fundamentals, 1.2-data-science-pipeline]        1  pending
# 2019-12-22           [1-fundamentals, DataToAction_v2.jpg]        1  pending
# 2019-12-22           [1-fundamentals, 2.2-excel-functions]        1  pending
# 2019-12-22  [1-fundamentals, 2.3-visualization-with-excel]        1  pending
# 2019-12-22             [1-fundamentals, 1.3-pipeline-demo]        1  pending
# 2019-12-22     [1-fundamentals, 1.2-data-science-pipeline]        1  pending
# 2019-12-22           [1-fundamentals, DataToAction_v2.jpg]        1  pending
# 2019-12-22             [1-fundamentals, 1.3-pipeline-demo]        1  pending
#
#              datetime
# date
# 2019-10-15 2019-10-15
# 2019-10-17 2019-10-17
# 2019-10-17 2019-10-17
# 2019-10-17 2019-10-17
# 2019-10-25 2019-10-25
# 2019-10-25 2019-10-25
# 2019-10-25 2019-10-25
# 2019-10-25 2019-10-25
# 2019-10-25 2019-10-25
# 2019-10-25 2019-10-25
# 2019-10-31 2019-10-31
# 2019-10-31 2019-10-31
# 2019-10-31 2019-10-31
# 2019-11-09 2019-11-09
# 2019-11-09 2019-11-09
# 2019-11-09 2019-11-09
# 2019-11-09 2019-11-09
# 2019-11-09 2019-11-09
# 2019-11-09 2019-11-09
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-11-30 2019-11-30
# 2019-11-30 2019-11-30
# 2019-11-30 2019-11-30
# 2019-12-05 2019-12-05
# 2019-12-05 2019-12-05
# 2019-12-05 2019-12-05
# 2019-12-05 2019-12-05
# 2019-12-05 2019-12-05
# 2019-12-05 2019-12-05
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22
# 2019-12-22 2019-12-22

# %%
#12-22
wd_2019_url = wd_2019[wd_2019.url == '4-python']
wd_2019_url.tail(40)
# Out:
#                 time                                 path  user_id  cohort_id  \
# date
# 2019-08-24  16:18:15                  4-python/1-overview      423       32.0
# 2019-09-10  08:38:54                  4-python/1-overview      420       32.0
# 2019-09-14  11:38:21                  4-python/1-overview      420       32.0
# 2019-09-14  11:38:23                 4-python/5-functions      420       32.0
# 2019-09-14  11:38:30                   4-python/6-imports      420       32.0
# 2019-09-14  11:38:36                     4-python/project      420       32.0
# 2019-09-14  11:38:39  4-python/3-data-types-and-variables      420       32.0
# 2019-09-14  11:39:26                  4-python/1-overview      420       32.0
# 2019-09-14  11:39:30    4-python/2-introduction-to-python      420       32.0
# 2019-09-14  12:49:02                  4-python/1-overview      420       32.0
# 2019-09-14  12:49:06    4-python/2-introduction-to-python      420       32.0
# 2019-09-14  12:55:02  4-python/3-data-types-and-variables      420       32.0
# 2019-09-14  12:55:08        4-python/4-control-structures      420       32.0
# 2019-09-14  12:55:13                 4-python/5-functions      420       32.0
# 2019-09-14  12:55:17   4-python/7.1-ds-libraries-overview      420       32.0
# 2019-09-14  12:55:19         4-python/7.4-intro-to-pandas      420       32.0
# 2019-09-14  12:55:36                  4-python/1-overview      420       32.0
# 2019-09-18  16:37:44                  4-python/1-overview       53       14.0
# 2019-09-18  16:39:56    4-python/2-introduction-to-python       53       14.0
# 2019-09-18  16:44:52  4-python/3-data-types-and-variables       53       14.0
# 2019-09-18  16:47:22        4-python/4-control-structures       53       14.0
# 2019-09-18  16:47:37                 4-python/5-functions       53       14.0
# 2019-09-18  16:47:47                   4-python/6-imports       53       14.0
# 2019-09-18  16:48:03                     4-python/project       53       14.0
# 2019-09-18  16:48:16   4-python/7.1-ds-libraries-overview       53       14.0
# 2019-10-01  16:48:29    4-python/2-introduction-to-python      249       24.0
# 2019-10-10  16:04:49                  4-python/1-overview      433       33.0
# 2019-10-11  09:05:55                  4-python/1-overview      450       33.0
# 2019-10-16  12:10:46                  4-python/1-overview      433       33.0
# 2019-10-16  12:10:53    4-python/2-introduction-to-python      433       33.0
# 2019-10-16  12:20:58        4-python/4-control-structures      433       33.0
# 2019-10-16  12:21:03  4-python/3-data-types-and-variables      433       33.0
# 2019-10-17  15:59:05                  4-python/1-overview      451       33.0
# 2019-11-10  19:09:51                  4-python/1-overview      450       33.0
# 2019-11-10  19:13:17    4-python/2-introduction-to-python      450       33.0
# 2019-11-12  14:25:49                     4-python/project      458       33.0
# 2019-11-12  14:25:52  4-python/3-data-types-and-variables      458       33.0
# 2019-11-12  14:26:01        4-python/4-control-structures      458       33.0
# 2019-11-12  14:26:30                 4-python/5-functions      458       33.0
# 2019-12-22  19:45:47            4-python/intro-to-sklearn       18       22.0
#
#             program_id               ip        name  start_date   end_date  \
# date
# 2019-08-24           2  192.171.117.210  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-10           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-14           2     97.105.19.58  Betelgeuse  2019-05-28 2019-10-08
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-09-18           1     97.105.19.58      Lassen  2016-07-18 2016-11-10
# 2019-10-01           2   167.24.104.150   Voyageurs  2018-05-29 2018-10-11
# 2019-10-10           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-11           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-16           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-16           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-16           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-16           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-10-17           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-11-10           2   72.177.232.192       Ceres  2019-07-15 2019-12-11
# 2019-11-10           2   72.177.232.192       Ceres  2019-07-15 2019-12-11
# 2019-11-12           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-11-12           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-11-12           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-11-12           2     97.105.19.58       Ceres  2019-07-15 2019-12-11
# 2019-12-22           2    45.20.117.182       Teddy  2018-01-08 2018-05-17
#
#                      created_at  program       url  \
# date
# 2019-08-24  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-10  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-14  2019-05-28 18:41:05  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-09-18  2016-07-18 19:06:27  web_dev  4-python
# 2019-10-01  2018-05-25 22:25:57  web_dev  4-python
# 2019-10-10  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-11  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-16  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-16  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-16  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-16  2019-07-15 16:57:21  web_dev  4-python
# 2019-10-17  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-10  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-10  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-12  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-12  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-12  2019-07-15 16:57:21  web_dev  4-python
# 2019-11-12  2019-07-15 16:57:21  web_dev  4-python
# 2019-12-22  2018-01-08 13:59:10  web_dev  4-python
#
#                                            subpath  counter   lesson  \
# date
# 2019-08-24                  [4-python, 1-overview]        1  pending
# 2019-09-10                  [4-python, 1-overview]        1  pending
# 2019-09-14                  [4-python, 1-overview]        1  pending
# 2019-09-14                 [4-python, 5-functions]        1  pending
# 2019-09-14                   [4-python, 6-imports]        1  pending
# 2019-09-14                     [4-python, project]        1  pending
# 2019-09-14  [4-python, 3-data-types-and-variables]        1  pending
# 2019-09-14                  [4-python, 1-overview]        1  pending
# 2019-09-14    [4-python, 2-introduction-to-python]        1  pending
# 2019-09-14                  [4-python, 1-overview]        1  pending
# 2019-09-14    [4-python, 2-introduction-to-python]        1  pending
# 2019-09-14  [4-python, 3-data-types-and-variables]        1  pending
# 2019-09-14        [4-python, 4-control-structures]        1  pending
# 2019-09-14                 [4-python, 5-functions]        1  pending
# 2019-09-14   [4-python, 7.1-ds-libraries-overview]        1  pending
# 2019-09-14         [4-python, 7.4-intro-to-pandas]        1  pending
# 2019-09-14                  [4-python, 1-overview]        1  pending
# 2019-09-18                  [4-python, 1-overview]        1  pending
# 2019-09-18    [4-python, 2-introduction-to-python]        1  pending
# 2019-09-18  [4-python, 3-data-types-and-variables]        1  pending
# 2019-09-18        [4-python, 4-control-structures]        1  pending
# 2019-09-18                 [4-python, 5-functions]        1  pending
# 2019-09-18                   [4-python, 6-imports]        1  pending
# 2019-09-18                     [4-python, project]        1  pending
# 2019-09-18   [4-python, 7.1-ds-libraries-overview]        1  pending
# 2019-10-01    [4-python, 2-introduction-to-python]        1  pending
# 2019-10-10                  [4-python, 1-overview]        1  pending
# 2019-10-11                  [4-python, 1-overview]        1  pending
# 2019-10-16                  [4-python, 1-overview]        1  pending
# 2019-10-16    [4-python, 2-introduction-to-python]        1  pending
# 2019-10-16        [4-python, 4-control-structures]        1  pending
# 2019-10-16  [4-python, 3-data-types-and-variables]        1  pending
# 2019-10-17                  [4-python, 1-overview]        1  pending
# 2019-11-10                  [4-python, 1-overview]        1  pending
# 2019-11-10    [4-python, 2-introduction-to-python]        1  pending
# 2019-11-12                     [4-python, project]        1  pending
# 2019-11-12  [4-python, 3-data-types-and-variables]        1  pending
# 2019-11-12        [4-python, 4-control-structures]        1  pending
# 2019-11-12                 [4-python, 5-functions]        1  pending
# 2019-12-22            [4-python, intro-to-sklearn]        1  pending
#
#              datetime
# date
# 2019-08-24 2019-08-24
# 2019-09-10 2019-09-10
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-14 2019-09-14
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-09-18 2019-09-18
# 2019-10-01 2019-10-01
# 2019-10-10 2019-10-10
# 2019-10-11 2019-10-11
# 2019-10-16 2019-10-16
# 2019-10-16 2019-10-16
# 2019-10-16 2019-10-16
# 2019-10-16 2019-10-16
# 2019-10-17 2019-10-17
# 2019-11-10 2019-11-10
# 2019-11-10 2019-11-10
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-11-12 2019-11-12
# 2019-12-22 2019-12-22

# %%
### we can see that the list hit of DS material from a webdev student was user 18 on 12-22
### date stamps seem they could have possibly been hitting for the quick hits (looking at fundamentals)
### also note that it looks like user 458 was potentially scraping on 11-12

# %%
#looking at DS to WebDev
ds_2019.url.value_counts().head(25)

#htmlm javascript, java-1 (lets look at these)
# Out:
# 1-fundamentals                      2558
# 4-python                            2181
# 6-regression                        2106
# 3-sql                               1910
# 5-stats                             1678
# 7-classification                    1556
#                                     1324
# 8-clustering                        1112
# appendix                            1105
# 11-nlp                               951
# 9-timeseries                         946
# 10-anomaly-detection                 910
# 2-storytelling                       757
# 12-distributed-ml                    429
# search                               337
# 13-advanced-topics                    64
# html-css                              26
# 3-vocabulary.md                       12
# javascript-i                          12
# toc                                    9
# 3-discrete-probabilistic-methods       9
# java-i                                 8
# spring                                 7
# login                                  5
# java-iii                               4
# Name: url, dtype: int64

# %%
ds_2019_url = ds_2019[ds_2019.url == 'html-css']
ds_2019_url.tail(20)
# Out:
#             date      time                   path  user_id  cohort_id  \
# 7501  2019-09-27  06:49:23               html-css      476       34.0
# 7502  2019-09-27  06:49:32  html-css/introduction      476       34.0
# 7503  2019-09-27  06:49:42      html-css/elements      476       34.0
# 16400 2019-11-25  14:26:13               html-css      476       34.0
# 16410 2019-11-25  14:26:28               html-css      476       34.0
# 16512 2019-11-26  10:37:29               html-css      476       34.0
# 16528 2019-11-26  10:54:59               html-css      476       34.0
# 16571 2019-11-26  15:53:24               html-css      467       34.0
# 16583 2019-11-26  16:42:20               html-css      472       34.0
# 16584 2019-11-26  16:42:25  html-css/introduction      472       34.0
# 16877 2019-12-03  10:04:39               html-css      467       34.0
# 16918 2019-12-03  11:49:28               html-css      467       34.0
# 17074 2019-12-04  13:35:09               html-css      476       34.0
# 18564 2019-12-13  21:14:27               html-css      476       34.0
# 18566 2019-12-13  21:14:51               html-css      476       34.0
# 18567 2019-12-13  21:15:23  html-css/introduction      476       34.0
# 18576 2019-12-14  16:44:09               html-css      476       34.0
# 18577 2019-12-14  16:44:16  html-css/introduction      476       34.0
# 18578 2019-12-14  16:44:18      html-css/elements      476       34.0
# 18579 2019-12-14  16:44:26         html-css/forms      476       34.0
#
#        program_id             ip   name  start_date   end_date  \
# 7501            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 7502            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 7503            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 16400           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16410           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16512           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16528           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16571           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16583           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16584           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16877           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16918           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 17074           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 18564           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18566           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18567           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18576           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18577           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18578           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 18579           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
#
#                 created_at       program       url                   subpath  \
# 7501   2019-08-20 14:38:55  data_science  html-css                [html-css]
# 7502   2019-08-20 14:38:55  data_science  html-css  [html-css, introduction]
# 7503   2019-08-20 14:38:55  data_science  html-css      [html-css, elements]
# 16400  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16410  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16512  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16528  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16571  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16583  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16584  2019-08-20 14:38:55  data_science  html-css  [html-css, introduction]
# 16877  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 16918  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 17074  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 18564  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 18566  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 18567  2019-08-20 14:38:55  data_science  html-css  [html-css, introduction]
# 18576  2019-08-20 14:38:55  data_science  html-css                [html-css]
# 18577  2019-08-20 14:38:55  data_science  html-css  [html-css, introduction]
# 18578  2019-08-20 14:38:55  data_science  html-css      [html-css, elements]
# 18579  2019-08-20 14:38:55  data_science  html-css         [html-css, forms]
#
#        counter   lesson     url2   datetime
# 7501         1  pending  pending 2019-09-27
# 7502         1  pending  pending 2019-09-27
# 7503         1  pending  pending 2019-09-27
# 16400        1  pending  pending 2019-11-25
# 16410        1  pending  pending 2019-11-25
# 16512        1  pending  pending 2019-11-26
# 16528        1  pending  pending 2019-11-26
# 16571        1  pending  pending 2019-11-26
# 16583        1  pending  pending 2019-11-26
# 16584        1  pending  pending 2019-11-26
# 16877        1  pending  pending 2019-12-03
# 16918        1  pending  pending 2019-12-03
# 17074        1  pending  pending 2019-12-04
# 18564        1  pending  pending 2019-12-13
# 18566        1  pending  pending 2019-12-13
# 18567        1  pending  pending 2019-12-13
# 18576        1  pending  pending 2019-12-14
# 18577        1  pending  pending 2019-12-14
# 18578        1  pending  pending 2019-12-14
# 18579        1  pending  pending 2019-12-14

# %%
ds_2019_url = ds_2019[ds_2019.url == 'javascript-i']
ds_2019_url.tail(20)
# Out:
#             date      time                          path  user_id  cohort_id  \
# 7318  2019-09-25  19:30:44                  javascript-i      476       34.0
# 7320  2019-09-25  19:31:07                  javascript-i      476       34.0
# 7322  2019-09-25  19:31:12                  javascript-i      476       34.0
# 7329  2019-09-25  19:32:23                  javascript-i      476       34.0
# 16401 2019-11-25  14:26:14                  javascript-i      476       34.0
# 16503 2019-11-26  10:31:16  javascript-i/bom-and-dom/dom      467       34.0
# 16513 2019-11-26  10:37:35                  javascript-i      476       34.0
# 16529 2019-11-26  10:55:05                  javascript-i      476       34.0
# 16569 2019-11-26  15:32:05     javascript-i/conditionals      472       34.0
# 16878 2019-12-03  10:04:40                  javascript-i      467       34.0
# 16919 2019-12-03  11:49:29                  javascript-i      467       34.0
# 18580 2019-12-14  16:46:24                  javascript-i      476       34.0
#
#        program_id             ip   name  start_date   end_date  \
# 7318            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 7320            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 7322            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 7329            3  136.50.49.145  Bayes  2019-08-19 2020-01-30
# 16401           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16503           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16513           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16529           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16569           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16878           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 16919           3   97.105.19.58  Bayes  2019-08-19 2020-01-30
# 18580           3  136.50.49.145  Bayes  2019-08-19 2020-01-30
#
#                 created_at       program           url  \
# 7318   2019-08-20 14:38:55  data_science  javascript-i
# 7320   2019-08-20 14:38:55  data_science  javascript-i
# 7322   2019-08-20 14:38:55  data_science  javascript-i
# 7329   2019-08-20 14:38:55  data_science  javascript-i
# 16401  2019-08-20 14:38:55  data_science  javascript-i
# 16503  2019-08-20 14:38:55  data_science  javascript-i
# 16513  2019-08-20 14:38:55  data_science  javascript-i
# 16529  2019-08-20 14:38:55  data_science  javascript-i
# 16569  2019-08-20 14:38:55  data_science  javascript-i
# 16878  2019-08-20 14:38:55  data_science  javascript-i
# 16919  2019-08-20 14:38:55  data_science  javascript-i
# 18580  2019-08-20 14:38:55  data_science  javascript-i
#
#                                 subpath  counter   lesson     url2   datetime
# 7318                     [javascript-i]        1  pending  pending 2019-09-25
# 7320                     [javascript-i]        1  pending  pending 2019-09-25
# 7322                     [javascript-i]        1  pending  pending 2019-09-25
# 7329                     [javascript-i]        1  pending  pending 2019-09-25
# 16401                    [javascript-i]        1  pending  pending 2019-11-25
# 16503  [javascript-i, bom-and-dom, dom]        1  pending  pending 2019-11-26
# 16513                    [javascript-i]        1  pending  pending 2019-11-26
# 16529                    [javascript-i]        1  pending  pending 2019-11-26
# 16569      [javascript-i, conditionals]        1  pending  pending 2019-11-26
# 16878                    [javascript-i]        1  pending  pending 2019-12-03
# 16919                    [javascript-i]        1  pending  pending 2019-12-03
# 18580                    [javascript-i]        1  pending  pending 2019-12-14

# %%
ds_2019_url = ds_2019[ds_2019.url == 'java-i']
ds_2019_url.tail(20)
# Out:
#             date      time               path  user_id  cohort_id  program_id  \
# 7321  2019-09-25  19:31:11             java-i      476       34.0           3
# 7323  2019-09-25  19:31:14             java-i      476       34.0           3
# 7330  2019-09-25  19:32:34             java-i      476       34.0           3
# 7331  2019-09-25  19:32:38             java-i      476       34.0           3
# 7332  2019-09-25  19:32:44  java-i/console-io      476       34.0           3
# 16404 2019-11-25  14:26:17             java-i      476       34.0           3
# 16515 2019-11-26  10:38:06             java-i      476       34.0           3
# 16881 2019-12-03  10:04:48             java-i      467       34.0           3
#
#                   ip   name  start_date   end_date           created_at  \
# 7321   136.50.49.145  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 7323   136.50.49.145  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 7330   136.50.49.145  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 7331   136.50.49.145  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 7332   136.50.49.145  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 16404   97.105.19.58  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 16515   97.105.19.58  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
# 16881   97.105.19.58  Bayes  2019-08-19 2020-01-30  2019-08-20 14:38:55
#
#             program     url               subpath  counter   lesson     url2  \
# 7321   data_science  java-i              [java-i]        1  pending  pending
# 7323   data_science  java-i              [java-i]        1  pending  pending
# 7330   data_science  java-i              [java-i]        1  pending  pending
# 7331   data_science  java-i              [java-i]        1  pending  pending
# 7332   data_science  java-i  [java-i, console-io]        1  pending  pending
# 16404  data_science  java-i              [java-i]        1  pending  pending
# 16515  data_science  java-i              [java-i]        1  pending  pending
# 16881  data_science  java-i              [java-i]        1  pending  pending
#
#         datetime
# 7321  2019-09-25
# 7323  2019-09-25
# 7330  2019-09-25
# 7331  2019-09-25
# 7332  2019-09-25
# 16404 2019-11-25
# 16515 2019-11-26
# 16881 2019-12-03

# %%
### last access of a WD student accessing DS was 12-22-19

# %% [markdown]
# ### answer:
# - The last access of a WD student accessing DS material was 12-22-19
# - The last access of a DS student accessing WD material was 12-14-19
#
# There is no determined cut off date for accessing the material until sometime in the last two weeks of 2019. There is also a few students who potentially could be scraping the material due to their access behavior.

# %%
########

# %%
# I have been wondering what technically '/' stands for - open search?
df.path.value_counts()
# Out:
# /                             39514
# toc                           16680
# javascript-i                  16386
# search/search_index.json      16185
# html-css                      11843
#                               ...
# About_NLP                         1
# 8.0_Intro_Module                  1
# introduction-to-matplotlib        1
# 2.0_Intro_Stats                   1
# 13.5_Tableau                      1
# Name: path, Length: 1844, dtype: int64

# %% [markdown]
# ### Followup quesitons
#
# - 1. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
# - 2. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students

# %%
### hit count under 200? for students

df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id  program_id            ip     name  start_date    end_date  \
# 0        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0           1  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0           2  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at  program           url  \
# 0  2016-06-14 19:52:26  web_dev
# 1  2016-06-14 19:52:26  web_dev       java-ii
# 2  2016-06-14 19:52:26  web_dev       java-ii
# 3  2016-06-14 19:52:26  web_dev        slides
# 4  2018-01-08 13:59:10  web_dev  javascript-i
#
#                                   subpath  counter
# 0                                    [, ]        1
# 1                               [java-ii]        1
# 2  [java-ii, object-oriented-programming]        1
# 3   [slides, object_oriented_programming]        1
# 4            [javascript-i, conditionals]        1

# %%
#groupby userid? value_counts?

# %%
# okay so added a count column that i can groupby user_id by?

df['counter'] = 1

# %%
df.tail()
# Out:
#               date      time                                   path  user_id  \
# 847317  2021-04-21  16:36:09                   jquery/personal-site      869
# 847318  2021-04-21  16:36:34  html-css/css-ii/bootstrap-grid-system      948
# 847319  2021-04-21  16:37:48                               java-iii      834
# 847320  2021-04-21  16:38:14                      java-iii/servlets      834
# 847324  2021-04-21  16:41:51           javascript-i/bom-and-dom/dom      875
#
#         cohort_id  program_id              ip     name  start_date  \
# 847317      135.0           2    136.50.98.51    Marco  2021-01-25
# 847318      138.0           2  104.48.214.211  Neptune  2021-03-15
# 847319      134.0           2     67.11.50.23     Luna  2020-12-07
# 847320      134.0           2     67.11.50.23     Luna  2020-12-07
# 847324      135.0           2  24.242.150.231    Marco  2021-01-25
#
#           end_date           created_at  program           url  \
# 847317  2021-07-19  2021-01-20 21:31:11  web_dev        jquery
# 847318  2021-09-03  2021-03-15 19:57:09  web_dev      html-css
# 847319  2021-06-08  2020-12-07 16:58:43  web_dev      java-iii
# 847320  2021-06-08  2020-12-07 16:58:43  web_dev      java-iii
# 847324  2021-07-19  2021-01-20 21:31:11  web_dev  javascript-i
#
#                                           subpath  counter
# 847317                    [jquery, personal-site]        1
# 847318  [html-css, css-ii, bootstrap-grid-system]        1
# 847319                                 [java-iii]        1
# 847320                       [java-iii, servlets]        1
# 847324           [javascript-i, bom-and-dom, dom]        1

# %%
#grouping user_id by counter sum column to get a number of hits
student_counter = (df.groupby('user_id').counter.sum().sort_values())
#change to DdataFrame
student_counter=pd.DataFrame(student_counter)

student_counter
# Out:
#          counter
# user_id
# 649            1
# 918            1
# 593            1
# 952            1
# 940            1
# ...          ...
# 423         3804
# 570         4584
# 344         5460
# 495         6451
# 53          8197
#
# [886 rows x 1 columns]

# %%
student_counter[(student_counter <= 50)].count()
# we have 111 students that represent less than 50 hits
# Out:
# counter    111
# dtype: int64

# %%
student_counter[(student_counter > 50)].count()
# we have 775 students that represent more than 50 hits
# Out:
# counter    775
# dtype: int64

# %%
#defining lowest 10%
bottom_ten = student_counter.counter.quantile(.10)

bottom_ten # value of 34 students
# Out:
# 34.0

# %%
##### greater than lowest ten right?
student_counter = student_counter[student_counter.counter < bottom_ten].reset_index()

# %%
student_counter
# Out:
#     user_id  counter
# 0       649        1
# 1       918        1
# 2       593        1
# 3       952        1
# 4       940        1
# ..      ...      ...
# 83      463       30
# 84      112       32
# 85      740       32
# 86      778       33
# 87      611       33
#
# [88 rows x 2 columns]

# %% [markdown]
# ### I can further attempt to answer this but the issues we face is that 5 cohorts end date is past the last date of the this dataframe giving unfair balance to those students in understanding the amount of hits.

# %%
student_counter.user_id
# Out:
# 0     649
# 1     918
# 2     593
# 3     952
# 4     940
#      ...
# 83    463
# 84    112
# 85    740
# 86    778
# 87    611
# Name: user_id, Length: 88, dtype: int64

# %%
# #going to concat to the main dataframe
# student_count = pd.concat([student_counter, df])
# student_count.isnull().sum()

# student_count.counter.sort_values().tail(20)

# %%
######

# %%
df.name.value_counts()
# Out:
# Ceres         40730
# Zion          38096
# Jupiter       37109
# Fortuna       36902
# Voyageurs     35636
# Ganymede      33844
# Apex          33568
# Deimos        32888
# Darden        32015
# Teddy         30926
# Hyperion      29855
# Betelgeuse    29356
# Ulysses       28534
# Europa        28033
# Xanadu        27749
# Bayes         26538
# Wrangell      25586
# Andromeda     25359
# Kalypso       23691
# Curie         21581
# Yosemite      20743
# Bash          17713
# Luna          16623
# Marco         16397
# Easley        14715
# Lassen         9587
# Arches         8890
# Florence       8562
# Sequoia        7444
# Neptune        7276
# Olympic        4954
# Kings          2845
# Pinnacles      2158
# Hampton        1712
# Oberon         1672
# Quincy         1237
# Niagara         755
# Mammoth         691
# Glacier         598
# Joshua          302
# Ike             253
# Badlands         93
# Franklin         72
# Apollo            5
# Denali            4
# Everglades        1
# Name: name, dtype: int64

# %%
df[['start_date', 'name']].value_counts()
# Out:
# start_date  name
# 2019-07-15  Ceres         40730
# 2019-01-22  Zion          38096
# 2020-09-21  Jupiter       37109
# 2020-01-13  Fortuna       36902
# 2018-05-29  Voyageurs     35636
# 2020-03-23  Ganymede      33844
# 2020-02-24  Apex          33568
# 2019-09-16  Deimos        32888
# 2020-07-13  Darden        32015
# 2018-01-08  Teddy         30926
# 2020-05-26  Hyperion      29855
# 2019-05-28  Betelgeuse    29356
# 2018-03-05  Ulysses       28534
# 2019-11-04  Europa        28033
# 2018-09-17  Xanadu        27749
# 2019-08-19  Bayes         26538
# 2018-07-23  Wrangell      25586
# 2019-03-18  Andromeda     25359
# 2020-11-02  Kalypso       23691
# 2020-02-03  Curie         21581
# 2018-11-05  Yosemite      20743
# 2020-07-20  Bash          17713
# 2020-12-07  Luna          16623
# 2021-01-25  Marco         16397
# 2020-12-07  Easley        14715
# 2016-07-18  Lassen         9587
# 2014-02-04  Arches         8890
# 2021-03-15  Florence       8562
# 2017-09-27  Sequoia        7444
# 2021-03-15  Neptune        7276
# 2017-02-06  Olympic        4954
# 2016-05-23  Kings          2845
# 2017-03-27  Pinnacles      2158
# 2015-09-22  Hampton        1712
# 2021-04-12  Oberon         1672
# 2017-06-05  Quincy         1237
# 2016-10-26  Niagara         755
# 2016-09-26  Mammoth         691
# 2015-06-05  Glacier         598
# 2016-03-08  Joshua          302
# 2016-01-20  Ike             253
# 2014-06-04  Badlands         93
# 2015-02-03  Franklin         72
# 2015-03-30  Apollo            5
# 2014-10-20  Denali            4
# 2014-11-18  Everglades        1
# dtype: int64

# %%
df_ds[['start_date', 'name']].value_counts()
# Out:
# start_date  name
# 2020-07-13  Darden      32015
# 2019-08-19  Bayes       26538
# 2020-02-03  Curie       21581
# 2020-12-07  Easley      14715
# 2021-03-15  Florence     8562
# dtype: int64

# %%
df_wd[['start_date', 'name']].value_counts()
# Out:
# start_date  name
# 2019-07-15  Ceres         40730
# 2019-01-22  Zion          38096
# 2020-09-21  Jupiter       37109
# 2020-01-13  Fortuna       36902
# 2018-05-29  Voyageurs     35636
# 2020-03-23  Ganymede      33844
# 2020-02-24  Apex          33568
# 2019-09-16  Deimos        32888
# 2018-01-08  Teddy         30926
# 2020-05-26  Hyperion      29855
# 2019-05-28  Betelgeuse    29356
# 2018-03-05  Ulysses       28534
# 2019-11-04  Europa        28033
# 2018-09-17  Xanadu        27749
# 2018-07-23  Wrangell      25586
# 2019-03-18  Andromeda     25359
# 2020-11-02  Kalypso       23691
# 2018-11-05  Yosemite      20743
# 2020-07-20  Bash          17713
# 2020-12-07  Luna          16623
# 2021-01-25  Marco         16397
# 2016-07-18  Lassen         9587
# 2014-02-04  Arches         8890
# 2017-09-27  Sequoia        7444
# 2021-03-15  Neptune        7276
# 2017-02-06  Olympic        4954
# 2016-05-23  Kings          2845
# 2017-03-27  Pinnacles      2158
# 2015-09-22  Hampton        1712
# 2021-04-12  Oberon         1672
# 2017-06-05  Quincy         1237
# 2016-10-26  Niagara         755
# 2016-09-26  Mammoth         691
# 2015-06-05  Glacier         598
# 2016-03-08  Joshua          302
# 2016-01-20  Ike             253
# 2014-06-04  Badlands         93
# 2015-02-03  Franklin         72
# 2015-03-30  Apollo            5
# 2014-10-20  Denali            4
# 2014-11-18  Everglades        1
# dtype: int64

# %%
df.start_date.max(), df.end_date.max()
# Out:
# ('2021-04-12', '2021-10-01')

# %%
df = df.reset_index()

# %%
### IMPORTANT TO NOTE THAT THE LAST DATE FOR THIS 

df.date.max()
# Out:
# '2021-04-21'

# %%
df.end_date.value_counts().sort_index()
# Out:
# 2014-04-22     8890
# 2014-08-22       93
# 2015-01-18        4
# 2015-02-24        1
# 2015-05-26       72
# 2015-07-29        5
# 2015-10-06      598
# 2016-02-06     1712
# 2016-05-12      253
# 2016-06-30      302
# 2016-09-15     2845
# 2016-11-10     9587
# 2017-02-02      691
# 2017-03-09      755
# 2017-05-25     4954
# 2017-07-20     2158
# 2017-09-22     1237
# 2018-02-15     7444
# 2018-05-17    30926
# 2018-07-19    28534
# 2018-10-11    35636
# 2018-11-29    25586
# 2019-02-08    27749
# 2019-04-03    20743
# 2019-06-04    38096
# 2019-07-30    25359
# 2019-10-08    29356
# 2019-12-11    40730
# 2020-01-30    26538
# 2020-02-27    32888
# 2020-04-17    28033
# 2020-06-23    36902
# 2020-07-07    21581
# 2020-07-29    33568
# 2020-08-20    33844
# 2020-11-10    29855
# 2021-01-12    32015
# 2021-01-21    17713
# 2021-03-30    37109
# 2021-05-04    23691
# 2021-06-08    31338
# 2021-07-19    16397
# 2021-09-03    15838
# 2021-10-01     1672
# Name: end_date, dtype: int64

# %%
df_wd[['end_date', 'name']].value_counts().sort_index()
# Out:
# end_date    name
# 2014-04-22  Arches         8890
# 2014-08-22  Badlands         93
# 2015-01-18  Denali            4
# 2015-02-24  Everglades        1
# 2015-05-26  Franklin         72
# 2015-07-29  Apollo            5
# 2015-10-06  Glacier         598
# 2016-02-06  Hampton        1712
# 2016-05-12  Ike             253
# 2016-06-30  Joshua          302
# 2016-09-15  Kings          2845
# 2016-11-10  Lassen         9587
# 2017-02-02  Mammoth         691
# 2017-03-09  Niagara         755
# 2017-05-25  Olympic        4954
# 2017-07-20  Pinnacles      2158
# 2017-09-22  Quincy         1237
# 2018-02-15  Sequoia        7444
# 2018-05-17  Teddy         30926
# 2018-07-19  Ulysses       28534
# 2018-10-11  Voyageurs     35636
# 2018-11-29  Wrangell      25586
# 2019-02-08  Xanadu        27749
# 2019-04-03  Yosemite      20743
# 2019-06-04  Zion          38096
# 2019-07-30  Andromeda     25359
# 2019-10-08  Betelgeuse    29356
# 2019-12-11  Ceres         40730
# 2020-02-27  Deimos        32888
# 2020-04-17  Europa        28033
# 2020-06-23  Fortuna       36902
# 2020-07-29  Apex          33568
# 2020-08-20  Ganymede      33844
# 2020-11-10  Hyperion      29855
# 2021-01-21  Bash          17713
# 2021-03-30  Jupiter       37109
# 2021-05-04  Kalypso       23691
# 2021-06-08  Luna          16623
# 2021-07-19  Marco         16397
# 2021-09-03  Neptune        7276
# 2021-10-01  Oberon         1672
# dtype: int64
